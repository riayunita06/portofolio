# %% [markdown]
# # Pra Proses Data

# %%
! pip install klib
# Out:
# Collecting klib
#   Downloading klib-1.3.2-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: jinja2>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from klib) (3.1.6)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.11/dist-packages (from klib) (3.10.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from klib) (2.0.2)
# Requirement already satisfied: pandas<3.0,>=1.4 in /usr/local/lib/python3.11/dist-packages (from klib) (2.2.2)
# Requirement already satisfied: plotly>=5.11.0 in /usr/local/lib/python3.11/dist-packages (from klib) (5.24.1)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from klib) (1.15.3)
# Collecting screeninfo>=0.8.1 (from klib)
#   Downloading screeninfo-0.8.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: seaborn>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from klib) (0.13.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=3.1.0->klib) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->klib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->klib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->klib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->klib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->klib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->klib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->klib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.6.0->klib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.4->klib) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0,>=1.4->klib) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.11.0->klib) (9.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->klib) (1.17.0)
# Downloading klib-1.3.2-py3-none-any.whl (23 kB)
# Downloading screeninfo-0.8.1-py3-none-any.whl (12 kB)
# Installing collected packages: screeninfo, klib
# Successfully installed klib-1.3.2 screeninfo-0.8.1

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import klib

# %%
df = pd.read_excel('/content/Data Pak Antok 2024.xlsx')
df
# Out:
#          Country Sovereign  Kategori  GDP (USDbn)  Real GDP Growth (%)  \
# 0    Switzerland       AAA         0          925                  1.3
# 1        Germany       AAA         0         4658                 -0.2
# 2        Denmark       AAA         0          426                  2.3
# 3     Luxembourg       AAA         0           93                  1.0
# 4    Netherlands       AAA         0         1225                  0.9
# ..           ...       ...       ...          ...                  ...
# 117   Bangladesh        B+         4          449                  4.2
# 118     Mongolia        B+         4           24                  5.0
# 119    Sri Lanka      CCC+         4           99                  5.0
# 120     Pakistan      CCC+         4          373                  2.5
# 121     Maldives        CC         4            7                  5.3
#
#      GDP Volatility (10 yr roll (%))  Consumer prices (annual avg. % growth)  \
# 0                                2.0                                     1.1
# 1                                2.1                                     2.5
# 2                                2.2                                     1.4
# 3                                2.6                                     2.3
# 4                                2.7                                     3.2
# ..                               ...                                     ...
# 117                              1.4                                     9.7
# 118                              3.6                                     6.8
# 119                              4.7                                     1.6
# 120                              2.5                                    23.4
# 121                             17.0                                     1.4
#
#      GG balance (% GDP)  GG debt (% GDP)  Comm. Dep (%CXR)  \
# 0                   0.5             25.0              16.5
# 1                  -2.6             63.6               9.3
# 2                   2.3             31.3              15.2
# 3                  -0.4             23.9               1.0
# 4                  -1.6             44.1              19.0
# ..                  ...              ...               ...
# 117                -4.6             36.6               2.1
# 118                 1.3             39.7              83.4
# 119                -6.8             99.1              15.2
# 120                -6.8             67.5              12.5
# 121               -12.1            113.7               7.2
#
#      GG int. exp. (% revenue)  GG dom. debt (% GDP)  GXD (% GDP)  \
# 0                         0.7                  21.9        258.6
# 1                         2.0                  36.7        178.1
# 2                         1.3                  25.5        161.5
# 3                         1.0                   6.1       4502.2
# 4                         1.6                  28.1        350.9
# ..                        ...                   ...          ...
# 117                      23.2                  21.7         23.8
# 118                       3.8                   0.5        159.3
# 119                      65.8                  63.2         57.1
# 120                      61.5                  44.7         35.1
# 121                      14.7                  74.9         66.4
#
#      GDP per. cap. (USD)  CAB (% GDP)
# 0                 102746          5.8
# 1                  54932          5.9
# 2                  71269         10.5
# 3                 137209         13.8
# 4                  68295          9.9
# ..                   ...          ...
# 117                 2606         -1.4
# 118                 6759        -10.0
# 119                 4515          1.3
# 120                 1581         -0.5
# 121                11778        -20.3
#
# [122 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# Country                                   0
# Sovereign                                 0
# Kategori                                  0
# GDP (USDbn)                               0
# Real GDP Growth (%)                       0
# GDP Volatility (10 yr roll (%))           0
# Consumer prices (annual avg. % growth)    0
# GG balance (% GDP)                        0
# GG debt (% GDP)                           0
# Comm. Dep (%CXR)                          0
# GG int. exp. (% revenue)                  0
# GG dom. debt (% GDP)                      0
# GXD (% GDP)                               0
# GDP per. cap. (USD)                       0
# CAB (% GDP)                               0
# dtype: int64

# %%
df.describe()
# Out:
#          Kategori   GDP (USDbn)  Real GDP Growth (%)  \
# count  122.000000    122.000000           122.000000
# mean     2.319672    874.598361             2.893443
# std      1.356139   3187.335146             2.335983
# min      0.000000      2.000000            -2.800000
# 25%      1.000000     43.000000             1.225000
# 50%      2.000000    123.000000             2.800000
# 75%      4.000000    488.000000             4.300000
# max      4.000000  29184.000000             9.400000
#
#        GDP Volatility (10 yr roll (%))  \
# count                       122.000000
# mean                          3.946721
# std                           3.509943
# min                           1.000000
# 25%                           2.300000
# 50%                           3.300000
# 75%                           4.400000
# max                          33.600000
#
#        Consumer prices (annual avg. % growth)  GG balance (% GDP)  \
# count                              122.000000          122.000000
# mean                                 6.784426           -2.604918
# std                                 22.403099            3.969884
# min                                 -0.400000          -18.500000
# 25%                                  1.700000           -4.600000
# 50%                                  2.950000           -2.900000
# 75%                                  4.500000           -0.850000
# max                                236.800000           11.700000
#
#        GG debt (% GDP)  Comm. Dep (%CXR)  GG int. exp. (% revenue)  \
# count       122.000000        122.000000                122.000000
# mean         59.633607         31.277049                 10.117213
# std          32.130276         25.339835                 10.705754
# min           0.000000          0.600000                  0.000000
# 25%          38.675000         11.650000                  3.500000
# 50%          54.650000         18.950000                  6.400000
# 75%          75.600000         52.600000                 13.800000
# max         218.200000         88.300000                 65.800000
#
#        GG dom. debt (% GDP)  GXD (% GDP)  GDP per. cap. (USD)  CAB (% GDP)
# count            122.000000   122.000000           122.000000   122.000000
# mean              33.886066   147.757377         25826.377049     0.898443
# std               26.211493   418.085772         27768.441869     7.735103
# min                0.000000     3.400000           631.000000   -20.300000
# 25%               15.150000    44.400000          4952.500000    -2.675000
# 50%               29.150000    70.450000         14263.000000     0.150000
# 75%               48.725000   124.250000         37496.250000     4.675000
# max              190.700000  4502.200000        137209.000000    33.800000

# %%
# prompt: buatkan syntax cek jenis data di tiap kolom

df.dtypes
# Out:
# Country                                    object
# Sovereign                                  object
# Kategori                                    int64
# GDP (USDbn)                                 int64
# Real GDP Growth (%)                       float64
# GDP Volatility (10 yr roll (%))           float64
# Consumer prices (annual avg. % growth)    float64
# GG balance (% GDP)                        float64
# GG debt (% GDP)                           float64
# Comm. Dep (%CXR)                          float64
# GG int. exp. (% revenue)                  float64
# GG dom. debt (% GDP)                      float64
# GXD (% GDP)                               float64
# GDP per. cap. (USD)                         int64
# CAB (% GDP)                               float64
# dtype: object

# %% [markdown]
# # Eksplorasi Data

# %% [markdown]
# ## Cek Korelasi antar Peubah Independen

# %%
df.corr(numeric_only=True)

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriks Korelasi Variabel Numerik')
plt.show()

# %% [markdown]
# Nilai korelasi antar peubah independen tidak menunjukkan tanda tanda multikolinearitas sehingga semua peubah independen diatas dapat digunakan

# %% [markdown]
# ## Ekplorasi Peubah Numerik

# %%
# prompt: buatkan syntax untuk membuat boxplot dari peubah numerik df, buatkan tampilan boxplotnya vertikal

import matplotlib.pyplot as plt
import numpy as np
# Assuming 'df' is your DataFrame and contains numerical columns you want to plot.
# Replace 'numerical_column' with the actual name of the numerical column you want to visualize.

numerical_columns = df.select_dtypes(include=np.number).columns

for column in numerical_columns:
  plt.figure(figsize=(8, 6))
  sns.boxplot(y=df[column], orient='v') # vertical boxplot
  plt.title(f'Boxplot of {column}')
  plt.ylabel(column)
  plt.show()

# %%
# prompt: buatkan eksplorasi histogram semua variabel numerik dari df

import numpy as np
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame and contains numerical columns you want to plot.
# Replace 'numerical_column' with the actual name of the numerical column you want to visualize.

numerical_columns = df.select_dtypes(include=np.number).columns

for column in numerical_columns:
  plt.figure(figsize=(8, 6))
  sns.histplot(df[column], kde=True)  # Histogram with KDE
  plt.title(f'Histogram of {column}')
  plt.xlabel(column)
  plt.ylabel('Frequency')
  plt.show()

# %% [markdown]
# ## Eksplorasi Sebaran Peubah Kategorik

# %%
# prompt: buatkan barchart untuk variabel kategori di df dan ganti nama elemennya dimana angka 1 = Sovereign Elite, 2 =Strong Investment Grade, 3 = Lower Investment Grade, 4 =Non-Investment Grade (Upper Tier), 5  =Distressed and Defaulted

# Assuming 'df' is your DataFrame and contains a categorical column named 'kategori'.
# Replace 'kategori' with the actual name of your categorical column.

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.countplot(x='Kategori', data=df)
plt.title('Distribution of Kategori')
plt.xlabel('Kategori')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent labels from overlapping
plt.show()

# %% [markdown]
# # Pembagian Data Train dan Testing

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
# prompt: buatkan variabel X dimana isinya selain peubah Country, Sovereign, Kategori

X = df.drop(columns=['Country', 'Sovereign', 'Kategori'])
Y = df['Kategori']

# %%
# prompt: buatkan syntax pembagian data train dan testing dari X dan Y

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (97, 12)
# (25, 12)
# (97,)
# (25,)

# %%
#normalisasi
scaler = MinMaxScaler()
skalax =scaler.fit(X_train)
X_train_scaled =skalax.transform(X_train)
X_train =pd.DataFrame(X_train_scaled, columns=X_train.columns)

X_test_Scaled =skalax.transform(X_test)
X_test= pd.DataFrame(X_test_Scaled, columns=X_test.columns)

# %% [markdown]
# # Pemodelan CatBoost dengan SMOTE

# %%
# --- Import library yang diperlukan ---
# !pip install catboost
import numpy as np
import pandas as pd

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_validate, KFold
from catboost import CatBoostClassifier
# Out:
# Collecting catboost
#   Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.15.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (9.1.2)
# Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl (99.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 9.2 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.8

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(random_state=11)
train_X_smote, train_y_smote = smote.fit_resample(X_train, Y_train)
print(train_X_smote.shape)
print(train_y_smote.shape)

print(train_y_smote.value_counts())
# Out:
# (145, 12)
# (145,)
# Kategori
# 4    29
# 1    29
# 3    29
# 2    29
# 0    29
# Name: count, dtype: int64

# %%
# nilai-nilai hyperparameter
param_dist = {
    'iterations': [25,50,100, 200, 300],
    'depth': [2,3],
    'learning_rate': [0.01, 0.05, 0.1, 0.3, 0.5],
    'l2_leaf_reg': [1, 3, 5, 7, 9],
    'loss_function': ['MultiClass']
}

# %% [markdown]
# ## Random Search dan Cross Validation

# %%
from sklearn.model_selection import RandomizedSearchCV

# Definisikan model awal dan parameter untuk RandomizedSearchCV
base_model = CatBoostClassifier(loss_function="MultiClass", verbose=0)

random_search = RandomizedSearchCV(
    base_model,
    param_distributions=param_dist,
    n_iter=50,
    scoring="accuracy",
    cv=5,                 # Cross-validation 5-fold
    random_state=42,      # Random seed untuk hasil yang dapat direproduksi
    n_jobs=-1,            # Menggunakan semua core CPU yang tersedia
)

# Melakukan random search dan fitting data training
random_search.fit(train_X_smote, train_y_smote)

# Menampilkan parameter terbaik
print(f"Best parameters found: {random_search.best_params_}")

# Menampilkan skor akurasi terbaik hasil CV
print(f"Best CV Score: {random_search.best_score_}")
# Out:
# Best parameters found: {'loss_function': 'MultiClass', 'learning_rate': 0.5, 'l2_leaf_reg': 1, 'iterations': 300, 'depth': 2}
# Best CV Score: 0.7586206896551724

# %% [markdown]
# ## Evaluasi Model Terbaik 1

# %%
# Memilih model terbaik
model_cb_cv = random_search.best_estimator_

# Memprediksi data uji
y_pred_cv = model_cb_cv.predict(train_X_smote)

# Menghitung akurasi
accuracy_cv = accuracy_score(train_y_smote, y_pred_cv)

print(f"Accuracy: {accuracy_cv}")

cm_cv = confusion_matrix(train_y_smote, y_pred_cv)
print("\nConfusion Matrix:\n", cm_cv)

cr_cv = classification_report(train_y_smote, y_pred_cv)
print("\nClassification Report:\n", cr_cv)
# Out:
# Accuracy: 1.0
#
# Confusion Matrix:
#  [[29  0  0  0  0]
#  [ 0 29  0  0  0]
#  [ 0  0 29  0  0]
#  [ 0  0  0 29  0]
#  [ 0  0  0  0 29]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        29
#            1       1.00      1.00      1.00        29
#            2       1.00      1.00      1.00        29
#            3       1.00      1.00      1.00        29
#            4       1.00      1.00      1.00        29
#
#     accuracy                           1.00       145
#    macro avg       1.00      1.00      1.00       145
# weighted avg       1.00      1.00      1.00       145

# %%
# Memilih model terbaik
model_cb_cv = random_search.best_estimator_

# Memprediksi data uji
y_pred_cv = model_cb_cv.predict(X_test)

# Menghitung akurasi
accuracy_cv = accuracy_score(Y_test, y_pred_cv)

print(f"Accuracy: {accuracy_cv}")

cm_cv = confusion_matrix(Y_test, y_pred_cv)
print("\nConfusion Matrix:\n", cm_cv)

cr_cv = classification_report(Y_test, y_pred_cv)
print("\nClassification Report:\n", cr_cv)
# Out:
# Accuracy: 0.6
#
# Confusion Matrix:
#  [[2 1 0 0 0]
#  [1 6 1 0 0]
#  [0 1 2 1 0]
#  [0 0 2 2 1]
#  [0 0 0 2 3]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67         3
#            1       0.75      0.75      0.75         8
#            2       0.40      0.50      0.44         4
#            3       0.40      0.40      0.40         5
#            4       0.75      0.60      0.67         5
#
#     accuracy                           0.60        25
#    macro avg       0.59      0.58      0.59        25
# weighted avg       0.61      0.60      0.60        25

# %% [markdown]
# ## Tuning Hyperparameter 1 dan Grid Search

# %%
from sklearn.model_selection import GridSearchCV
from catboost import CatBoostClassifier

# Nilai-nilai hyperparameter
param_grid = {
'iterations': [25, 50, 100],
    'depth': [2, 3],
    'learning_rate': [0.01, 0.05, 0.1, 0.3, 0.5],
    'l2_leaf_reg': [1, 3, 5, 7, 9],
    'loss_function':['MultiClass']
}

# Definisikan model awal
base_model = CatBoostClassifier(loss_function="MultiClass", verbose=0)

# Definisikan GridSearchCV
grid_search = GridSearchCV(
    base_model,
    param_grid=param_grid,
    scoring="accuracy",
    cv=5,                 # Cross-validation 5-fold
    n_jobs=-1,            # Menggunakan semua core CPU yang tersedia
)

# Melakukan grid search dan fitting data training
grid_search.fit(train_X_smote, train_y_smote)

# Menampilkan parameter terbaik
print(f"Best parameters found: {grid_search.best_params_}")

# Menampilkan skor akurasi terbaik hasil CV
print(f"Best CV Score: {grid_search.best_score_}")
# Out:
# Best parameters found: {'depth': 2, 'iterations': 100, 'l2_leaf_reg': 1, 'learning_rate': 0.5, 'loss_function': 'MultiClass'}
# Best CV Score: 0.7448275862068965

# %%
# Memilih model terbaik
model_cb_cv = grid_search.best_estimator_

# Memprediksi data uji
y_pred_cv = model_cb_cv.predict(train_X_smote)

# Menghitung akurasi
accuracy_cv = accuracy_score(train_y_smote, y_pred_cv)

print(f"Accuracy: {accuracy_cv}")

# Menghitung confusion matrix
cm_cv = confusion_matrix(train_y_smote, y_pred_cv)
print("\nConfusion Matrix:\n", cm_cv)

# Menampilkan classification report
cr_cv = classification_report(train_y_smote, y_pred_cv)
print("\nClassification Report:\n", cr_cv)
# Out:
# Accuracy: 1.0
#
# Confusion Matrix:
#  [[29  0  0  0  0]
#  [ 0 29  0  0  0]
#  [ 0  0 29  0  0]
#  [ 0  0  0 29  0]
#  [ 0  0  0  0 29]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        29
#            1       1.00      1.00      1.00        29
#            2       1.00      1.00      1.00        29
#            3       1.00      1.00      1.00        29
#            4       1.00      1.00      1.00        29
#
#     accuracy                           1.00       145
#    macro avg       1.00      1.00      1.00       145
# weighted avg       1.00      1.00      1.00       145

# %%
# Memilih model terbaik
model_cb_cv = grid_search.best_estimator_

# Memprediksi data uji
y_pred_cv = model_cb_cv.predict(X_test)

# Menghitung akurasi
accuracy_cv = accuracy_score(Y_test, y_pred_cv)

print(f"Accuracy: {accuracy_cv}")
# Evaluasi metrik
print("Akurasi:", accuracy_score(Y_test, y_pred_cv))
print("Precision (macro):", precision_score(Y_test, y_pred_cv, average='macro'))
print("Recall (macro):", recall_score(Y_test, y_pred_cv, average='macro'))
print("F1 Score (macro):", f1_score(Y_test, y_pred_cv, average='macro'))

# Menghitung confusion matrix
cm_cv = confusion_matrix(Y_test, y_pred_cv)
print("\nConfusion Matrix:\n", cm_cv)

# Menampilkan classification report
cr_cv = classification_report(Y_test, y_pred_cv)
print("\nClassification Report:\n", cr_cv)
# Out:
# Accuracy: 0.6
# Akurasi: 0.6
# Precision (macro): 0.5766666666666665
# Recall (macro): 0.5833333333333334
# F1 Score (macro): 0.5733333333333333
#
# Confusion Matrix:
#  [[2 1 0 0 0]
#  [1 6 1 0 0]
#  [0 1 2 1 0]
#  [0 0 3 1 1]
#  [0 0 0 1 4]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67         3
#            1       0.75      0.75      0.75         8
#            2       0.33      0.50      0.40         4
#            3       0.33      0.20      0.25         5
#            4       0.80      0.80      0.80         5
#
#     accuracy                           0.60        25
#    macro avg       0.58      0.58      0.57        25
# weighted avg       0.60      0.60      0.59        25

# %% [markdown]
# ## Tuning Hyperparamater 2 dan Grid Search

# %%
from sklearn.model_selection import GridSearchCV
from catboost import CatBoostClassifier

# Nilai-nilai hyperparameter
param_grid = {
'iterations': [25],
    'depth': [2,3,4],
    'learning_rate': [0.01, 0.05],
    'l2_leaf_reg': [1, 3],
    'loss_function':['MultiClass']
}

# Definisikan model awal
base_model = CatBoostClassifier(loss_function="MultiClass", verbose=0)

# Definisikan GridSearchCV
grid_search = GridSearchCV(
    base_model,
    param_grid=param_grid,
    scoring="accuracy",
    cv=5,                 # Cross-validation 5-fold
    n_jobs=-1,            # Menggunakan semua core CPU yang tersedia
)

# Melakukan grid search dan fitting data training
grid_search.fit(train_X_smote, train_y_smote)

# Menampilkan parameter terbaik
print(f"Best parameters found: {grid_search.best_params_}")

# Menampilkan skor akurasi terbaik hasil CV
print(f"Best CV Score: {grid_search.best_score_}")
# Out:
# Best parameters found: {'depth': 2, 'iterations': 25, 'l2_leaf_reg': 1, 'learning_rate': 0.05, 'loss_function': 'MultiClass'}
# Best CV Score: 0.6620689655172413

# %% [markdown]
# # Best Model

# %%
# Memilih model terbaik
model_cb_cv_best = grid_search.best_estimator_

# Memprediksi data uji
y_pred_cv = model_cb_cv_best.predict(train_X_smote)

# Menghitung akurasi
accuracy_cv = accuracy_score(train_y_smote, y_pred_cv)

print(f"Accuracy: {accuracy_cv}")

# Menghitung confusion matrix
cm_cv = confusion_matrix(train_y_smote, y_pred_cv)
print("\nConfusion Matrix:\n", cm_cv)

# Menampilkan classification report
cr_cv = classification_report(train_y_smote, y_pred_cv)
print("\nClassification Report:\n", cr_cv)
# Out:
# Accuracy: 0.8
#
# Confusion Matrix:
#  [[29  0  0  0  0]
#  [ 6 20  3  0  0]
#  [ 0  2 25  1  1]
#  [ 0  2  4 20  3]
#  [ 0  1  2  4 22]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        29
#            1       0.80      0.69      0.74        29
#            2       0.74      0.86      0.79        29
#            3       0.80      0.69      0.74        29
#            4       0.85      0.76      0.80        29
#
#     accuracy                           0.80       145
#    macro avg       0.80      0.80      0.80       145
# weighted avg       0.80      0.80      0.80       145

# %%
# Memilih model terbaik
model_cb_cv_best = grid_search.best_estimator_

# Memprediksi data uji
y_pred_cv = model_cb_cv_best.predict(X_test)

# Menghitung akurasi
accuracy_cv = accuracy_score(Y_test, y_pred_cv)

print(f"Accuracy: {accuracy_cv}")
# Evaluasi metrik
print("Akurasi:", accuracy_score(Y_test, y_pred_cv))
print("Precision (macro):", precision_score(Y_test, y_pred_cv, average='macro'))
print("Recall (macro):", recall_score(Y_test, y_pred_cv, average='macro'))
print("F1 Score (macro):", f1_score(Y_test, y_pred_cv, average='macro'))

# Menghitung confusion matrix
cm_cv = confusion_matrix(Y_test, y_pred_cv)
print("\nConfusion Matrix:\n", cm_cv)

# Menampilkan classification report
cr_cv = classification_report(Y_test, y_pred_cv)
print("\nClassification Report:\n", cr_cv)
# Out:
# Accuracy: 0.72
# Akurasi: 0.72
# Precision (macro): 0.75
# Recall (macro): 0.7133333333333333
# F1 Score (macro): 0.6994372294372294
#
# Confusion Matrix:
#  [[2 1 0 0 0]
#  [1 6 1 0 0]
#  [0 1 3 0 0]
#  [0 0 2 2 1]
#  [0 0 0 0 5]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67         3
#            1       0.75      0.75      0.75         8
#            2       0.50      0.75      0.60         4
#            3       1.00      0.40      0.57         5
#            4       0.83      1.00      0.91         5
#
#     accuracy                           0.72        25
#    macro avg       0.75      0.71      0.70        25
# weighted avg       0.77      0.72      0.71        25

# %%
from sklearn.model_selection import GridSearchCV
from catboost import CatBoostClassifier

# Nilai-nilai hyperparameter
param_grid = {
'iterations': [25],
    'depth': [2,3,4],
    'learning_rate': [0.01, 0.05, 0.1],
    'l2_leaf_reg': [1, 3],
    'loss_function':['MultiClass']
}

# Definisikan model awal
base_model = CatBoostClassifier(loss_function="MultiClass", verbose=0)

# Definisikan GridSearchCV
grid_search = GridSearchCV(
    base_model,
    param_grid=param_grid,
    scoring="accuracy",
    cv=5,                 # Cross-validation 5-fold
    n_jobs=-1,            # Menggunakan semua core CPU yang tersedia
)

# Melakukan grid search dan fitting data training
grid_search.fit(train_X_smote, train_y_smote)

# Menampilkan parameter terbaik
print(f"Best parameters found: {grid_search.best_params_}")

# Menampilkan skor akurasi terbaik hasil CV
print(f"Best CV Score: {grid_search.best_score_}")
# Out:
# Best parameters found: {'depth': 4, 'iterations': 25, 'l2_leaf_reg': 1, 'learning_rate': 0.1, 'loss_function': 'MultiClass'}
# Best CV Score: 0.689655172413793

# %%
# Memilih model terbaik
model_cb_cv = grid_search.best_estimator_

# Memprediksi data uji
y_pred_cv = model_cb_cv.predict(train_X_smote)

# Menghitung akurasi
accuracy_cv = accuracy_score(train_y_smote, y_pred_cv)

print(f"Accuracy: {accuracy_cv}")

# Menghitung confusion matrix
cm_cv = confusion_matrix(train_y_smote, y_pred_cv)
print("\nConfusion Matrix:\n", cm_cv)

# Menampilkan classification report
cr_cv = classification_report(train_y_smote, y_pred_cv)
print("\nClassification Report:\n", cr_cv)
# Out:
# Accuracy: 0.903448275862069
#
# Confusion Matrix:
#  [[29  0  0  0  0]
#  [ 0 28  1  0  0]
#  [ 0  2 27  0  0]
#  [ 0  0  4 22  3]
#  [ 0  1  1  2 25]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        29
#            1       0.90      0.97      0.93        29
#            2       0.82      0.93      0.87        29
#            3       0.92      0.76      0.83        29
#            4       0.89      0.86      0.88        29
#
#     accuracy                           0.90       145
#    macro avg       0.91      0.90      0.90       145
# weighted avg       0.91      0.90      0.90       145

# %%
# Memilih model terbaik
model_cb_cv = grid_search.best_estimator_

# Memprediksi data uji
y_pred_cv = model_cb_cv.predict(X_test)

# Menghitung akurasi
accuracy_cv = accuracy_score(Y_test, y_pred_cv)

print(f"Accuracy: {accuracy_cv}")
# Evaluasi metrik
print("Akurasi:", accuracy_score(Y_test, y_pred_cv))
print("Precision (macro):", precision_score(Y_test, y_pred_cv, average='macro'))
print("Recall (macro):", recall_score(Y_test, y_pred_cv, average='macro'))
print("F1 Score (macro):", f1_score(Y_test, y_pred_cv, average='macro'))

# Menghitung confusion matrix
cm_cv = confusion_matrix(Y_test, y_pred_cv)
print("\nConfusion Matrix:\n", cm_cv)

# Menampilkan classification report
cr_cv = classification_report(Y_test, y_pred_cv)
print("\nClassification Report:\n", cr_cv)
# Out:
# Accuracy: 0.56
# Akurasi: 0.56
# Precision (macro): 0.5414285714285714
# Recall (macro): 0.5433333333333333
# F1 Score (macro): 0.5377777777777778
#
# Confusion Matrix:
#  [[2 1 0 0 0]
#  [1 6 1 0 0]
#  [0 0 2 1 1]
#  [0 0 3 1 1]
#  [0 0 0 2 3]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67         3
#            1       0.86      0.75      0.80         8
#            2       0.33      0.50      0.40         4
#            3       0.25      0.20      0.22         5
#            4       0.60      0.60      0.60         5
#
#     accuracy                           0.56        25
#    macro avg       0.54      0.54      0.54        25
# weighted avg       0.58      0.56      0.56        25

# %%
from sklearn.model_selection import GridSearchCV
from catboost import CatBoostClassifier

# Nilai-nilai hyperparameter
param_grid = {
'iterations': [25,50],
    'depth': [4],
    'learning_rate': [0.01, 0.05],
    'l2_leaf_reg': [2],
    'loss_function':['MultiClass']
}

# Definisikan model awal
base_model = CatBoostClassifier(loss_function="MultiClass", verbose=0)

# Definisikan GridSearchCV
grid_search = GridSearchCV(
    base_model,
    param_grid=param_grid,
    scoring="accuracy",
    cv=5,                 # Cross-validation 5-fold
    n_jobs=-1,            # Menggunakan semua core CPU yang tersedia
)

# Melakukan grid search dan fitting data training
grid_search.fit(train_X_smote, train_y_smote)

# Menampilkan parameter terbaik
print(f"Best parameters found: {grid_search.best_params_}")

# Menampilkan skor akurasi terbaik hasil CV
print(f"Best CV Score: {grid_search.best_score_}")
# Out:
# Best parameters found: {'depth': 4, 'iterations': 50, 'l2_leaf_reg': 2, 'learning_rate': 0.05, 'loss_function': 'MultiClass'}
# Best CV Score: 0.689655172413793

# %%
# Memilih model terbaik
model_cb_cv = grid_search.best_estimator_

# Memprediksi data uji
y_pred_cv = model_cb_cv.predict(train_X_smote)

# Menghitung akurasi
accuracy_cv = accuracy_score(train_y_smote, y_pred_cv)

print(f"Accuracy: {accuracy_cv}")

# Menghitung confusion matrix
cm_cv = confusion_matrix(train_y_smote, y_pred_cv)
print("\nConfusion Matrix:\n", cm_cv)

# Menampilkan classification report
cr_cv = classification_report(train_y_smote, y_pred_cv)
print("\nClassification Report:\n", cr_cv)
# Out:
# Accuracy: 0.9103448275862069
#
# Confusion Matrix:
#  [[29  0  0  0  0]
#  [ 1 27  1  0  0]
#  [ 0  2 27  0  0]
#  [ 0  1  4 23  1]
#  [ 0  1  1  1 26]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        29
#            1       0.87      0.93      0.90        29
#            2       0.82      0.93      0.87        29
#            3       0.96      0.79      0.87        29
#            4       0.96      0.90      0.93        29
#
#     accuracy                           0.91       145
#    macro avg       0.92      0.91      0.91       145
# weighted avg       0.92      0.91      0.91       145

# %%
# Memilih model terbaik
model_cb_cv = grid_search.best_estimator_

# Memprediksi data uji
y_pred_cv = model_cb_cv.predict(X_test)

# Menghitung akurasi
accuracy_cv = accuracy_score(Y_test, y_pred_cv)

print(f"Accuracy: {accuracy_cv}")
# Evaluasi metrik
print("Akurasi:", accuracy_score(Y_test, y_pred_cv))
print("Precision (macro):", precision_score(Y_test, y_pred_cv, average='macro'))
print("Recall (macro):", recall_score(Y_test, y_pred_cv, average='macro'))
print("F1 Score (macro):", f1_score(Y_test, y_pred_cv, average='macro'))

# Menghitung confusion matrix
cm_cv = confusion_matrix(Y_test, y_pred_cv)
print("\nConfusion Matrix:\n", cm_cv)

# Menampilkan classification report
cr_cv = classification_report(Y_test, y_pred_cv)
print("\nClassification Report:\n", cr_cv)
# Out:
# Accuracy: 0.56
# Akurasi: 0.56
# Precision (macro): 0.55
# Recall (macro): 0.5433333333333333
# F1 Score (macro): 0.5411111111111111
#
# Confusion Matrix:
#  [[2 1 0 0 0]
#  [1 6 1 0 0]
#  [0 1 2 1 0]
#  [0 0 3 1 1]
#  [0 0 0 2 3]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67         3
#            1       0.75      0.75      0.75         8
#            2       0.33      0.50      0.40         4
#            3       0.25      0.20      0.22         5
#            4       0.75      0.60      0.67         5
#
#     accuracy                           0.56        25
#    macro avg       0.55      0.54      0.54        25
# weighted avg       0.57      0.56      0.56        25

# %%
from sklearn.model_selection import GridSearchCV
from catboost import CatBoostClassifier

# Nilai-nilai hyperparameter
param_grid = {
'iterations': [25],
    'depth': [2,3],
    'learning_rate': [0.01, 0.05],
    'l2_leaf_reg': [1, 3],
    'loss_function':['MultiClass']
}

# Definisikan model awal
base_model = CatBoostClassifier(loss_function="MultiClass", verbose=0)

# Definisikan GridSearchCV
grid_search = GridSearchCV(
    base_model,
    param_grid=param_grid,
    scoring="accuracy",
    cv=5,                 # Cross-validation 5-fold
    n_jobs=-1,            # Menggunakan semua core CPU yang tersedia
)

# Melakukan grid search dan fitting data training
grid_search.fit(train_X_smote, train_y_smote)

# Menampilkan parameter terbaik
print(f"Best parameters found: {grid_search.best_params_}")

# Menampilkan skor akurasi terbaik hasil CV
print(f"Best CV Score: {grid_search.best_score_}")
# Out:
# Best parameters found: {'depth': 2, 'iterations': 25, 'l2_leaf_reg': 1, 'learning_rate': 0.05, 'loss_function': 'MultiClass'}
# Best CV Score: 0.6620689655172413

# %%
# Memilih model terbaik
model_cb_cv = grid_search.best_estimator_

# Memprediksi data uji
y_pred_cv = model_cb_cv.predict(train_X_smote)

# Menghitung akurasi
accuracy_cv = accuracy_score(train_y_smote, y_pred_cv)

print(f"Accuracy: {accuracy_cv}")

# Menghitung confusion matrix
cm_cv = confusion_matrix(train_y_smote, y_pred_cv)
print("\nConfusion Matrix:\n", cm_cv)

# Menampilkan classification report
cr_cv = classification_report(train_y_smote, y_pred_cv)
print("\nClassification Report:\n", cr_cv)
# Out:
# Accuracy: 0.8
#
# Confusion Matrix:
#  [[29  0  0  0  0]
#  [ 6 20  3  0  0]
#  [ 0  2 25  1  1]
#  [ 0  2  4 20  3]
#  [ 0  1  2  4 22]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        29
#            1       0.80      0.69      0.74        29
#            2       0.74      0.86      0.79        29
#            3       0.80      0.69      0.74        29
#            4       0.85      0.76      0.80        29
#
#     accuracy                           0.80       145
#    macro avg       0.80      0.80      0.80       145
# weighted avg       0.80      0.80      0.80       145

# %%
# Memilih model terbaik
model_cb_cv = grid_search.best_estimator_

# Memprediksi data uji
y_pred_cv = model_cb_cv.predict(X_test)

# Menghitung akurasi
accuracy_cv = accuracy_score(Y_test, y_pred_cv)

print(f"Accuracy: {accuracy_cv}")
# Evaluasi metrik
print("Akurasi:", accuracy_score(Y_test, y_pred_cv))
print("Precision (macro):", precision_score(Y_test, y_pred_cv, average='macro'))
print("Recall (macro):", recall_score(Y_test, y_pred_cv, average='macro'))
print("F1 Score (macro):", f1_score(Y_test, y_pred_cv, average='macro'))

# Menghitung confusion matrix
cm_cv = confusion_matrix(Y_test, y_pred_cv)
print("\nConfusion Matrix:\n", cm_cv)

# Menampilkan classification report
cr_cv = classification_report(Y_test, y_pred_cv)
print("\nClassification Report:\n", cr_cv)
# Out:
# Accuracy: 0.72
# Akurasi: 0.72
# Precision (macro): 0.75
# Recall (macro): 0.7133333333333333
# F1 Score (macro): 0.6994372294372294
#
# Confusion Matrix:
#  [[2 1 0 0 0]
#  [1 6 1 0 0]
#  [0 1 3 0 0]
#  [0 0 2 2 1]
#  [0 0 0 0 5]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67         3
#            1       0.75      0.75      0.75         8
#            2       0.50      0.75      0.60         4
#            3       1.00      0.40      0.57         5
#            4       0.83      1.00      0.91         5
#
#     accuracy                           0.72        25
#    macro avg       0.75      0.71      0.70        25
# weighted avg       0.77      0.72      0.71        25

# %% [markdown]
# ## Paling Oke

# %%
from sklearn.model_selection import GridSearchCV
from catboost import CatBoostClassifier

# Nilai-nilai hyperparameter
param_grid = {
'iterations': [25],
    'depth': [2,3],
    'learning_rate': [0.01, 0.05],
    'l2_leaf_reg': [2],
    'loss_function':['MultiClass']
}

# Definisikan model awal
base_model = CatBoostClassifier(loss_function="MultiClass", verbose=0)

# Definisikan GridSearchCV
grid_search = GridSearchCV(
    base_model,
    param_grid=param_grid,
    scoring="accuracy",
    cv=5,                 # Cross-validation 5-fold
    n_jobs=-1,            # Menggunakan semua core CPU yang tersedia
)

# Melakukan grid search dan fitting data training
grid_search.fit(train_X_smote, train_y_smote)

# Menampilkan parameter terbaik
print(f"Best parameters found: {grid_search.best_params_}")

# Menampilkan skor akurasi terbaik hasil CV
print(f"Best CV Score: {grid_search.best_score_}")
# Out:
# Best parameters found: {'depth': 2, 'iterations': 25, 'l2_leaf_reg': 2, 'learning_rate': 0.05, 'loss_function': 'MultiClass'}
# Best CV Score: 0.6413793103448275

# %%
# Memilih model terbaik
model_cb_cv = grid_search.best_estimator_

# Memprediksi data uji
y_pred_cv = model_cb_cv.predict(train_X_smote)

# Menghitung akurasi
accuracy_cv = accuracy_score(train_y_smote, y_pred_cv)

print(f"Accuracy: {accuracy_cv}")

# Menghitung confusion matrix
cm_cv = confusion_matrix(train_y_smote, y_pred_cv)
print("\nConfusion Matrix:\n", cm_cv)

# Menampilkan classification report
cr_cv = classification_report(train_y_smote, y_pred_cv)
print("\nClassification Report:\n", cr_cv)
# Out:
# Accuracy: 0.7724137931034483
#
# Confusion Matrix:
#  [[29  0  0  0  0]
#  [ 6 20  3  0  0]
#  [ 0  2 24  1  2]
#  [ 0  2  5 17  5]
#  [ 0  1  2  4 22]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        29
#            1       0.80      0.69      0.74        29
#            2       0.71      0.83      0.76        29
#            3       0.77      0.59      0.67        29
#            4       0.76      0.76      0.76        29
#
#     accuracy                           0.77       145
#    macro avg       0.77      0.77      0.77       145
# weighted avg       0.77      0.77      0.77       145

# %%
# Memilih model terbaik
model_cb_cv = grid_search.best_estimator_

# Memprediksi data uji
y_pred_cv = model_cb_cv.predict(X_test)

# Menghitung akurasi
accuracy_cv = accuracy_score(Y_test, y_pred_cv)

print(f"Accuracy: {accuracy_cv}")
# Evaluasi metrik
print("Akurasi:", accuracy_score(Y_test, y_pred_cv))
print("Precision (macro):", precision_score(Y_test, y_pred_cv, average='macro'))
print("Recall (macro):", recall_score(Y_test, y_pred_cv, average='macro'))
print("F1 Score (macro):", f1_score(Y_test, y_pred_cv, average='macro'))

# Menghitung confusion matrix
cm_cv = confusion_matrix(Y_test, y_pred_cv)
print("\nConfusion Matrix:\n", cm_cv)

# Menampilkan classification report
cr_cv = classification_report(Y_test, y_pred_cv)
print("\nClassification Report:\n", cr_cv)
# Out:
# Accuracy: 0.72
# Akurasi: 0.72
# Precision (macro): 0.75
# Recall (macro): 0.7133333333333333
# F1 Score (macro): 0.6994372294372294
#
# Confusion Matrix:
#  [[2 1 0 0 0]
#  [1 6 1 0 0]
#  [0 1 3 0 0]
#  [0 0 2 2 1]
#  [0 0 0 0 5]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67         3
#            1       0.75      0.75      0.75         8
#            2       0.50      0.75      0.60         4
#            3       1.00      0.40      0.57         5
#            4       0.83      1.00      0.91         5
#
#     accuracy                           0.72        25
#    macro avg       0.75      0.71      0.70        25
# weighted avg       0.77      0.72      0.71        25

# %%
import joblib

model_filename = 'model_catboost.pkl'
joblib.dump(model_cb_cv_best, model_filename)
print(f"Model saved to {model_filename}")
# Out:
# Model saved to model_catboost.pkl

# %%
loaded_model = joblib.load(model_filename)
print(f"Model loaded from {model_filename}")
# Out:
# Model loaded from model_catboost.pkl

# %% [markdown]
# ## Feature Important Global

# %%
import matplotlib.pyplot as plt

# Menampilkan Fitur Importance
feature_importances = loaded_model.feature_importances_
feature_names = X.columns

# Membuat DataFrame untuk Fitur Importance
feature_importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=False)

# Menampilkan DataFrame Fitur Importance
print("\nFeature Importances:")
print(feature_importance_df)

# Membuat Plot Fitur Importance
plt.figure(figsize=(6, 4))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importances')
plt.gca().invert_yaxis()
plt.show()
# Out:
# Feature Importances:
#                                    Feature  Importance
# 10                     GDP per. cap. (USD)   40.146587
# 11                             CAB (% GDP)   15.477206
# 0                              GDP (USDbn)   14.661335
# 9                              GXD (% GDP)   11.459170
# 7                 GG int. exp. (% revenue)    9.474506
# 2          GDP Volatility (10 yr roll (%))    2.926901
# 3   Consumer prices (annual avg. % growth)    2.865007
# 4                       GG balance (% GDP)    1.621220
# 6                         Comm. Dep (%CXR)    0.534611
# 1                      Real GDP Growth (%)    0.472011
# 5                          GG debt (% GDP)    0.361446
# 8                     GG dom. debt (% GDP)    0.000000

# %% [markdown]
# ## Peran Peubah secara Global

# %%
import shap
import tensorflow

#save nilai
explainer = shap.TreeExplainer(model_cb_cv_best)
shap.initjs()
shap_values_cat = explainer(X_test)
prediksi = model_cb_cv.predict(X_test)

new_shap_values = []
for i, pred in enumerate(prediksi):
    new_shap_values.append(shap_values_cat.values[i][:,pred])  # ambil shap value untuk kelas ke-pred
new_shap_values = np.array(new_shap_values)
new_shap_values = np.squeeze(new_shap_values)
print("New shape:", new_shap_values.shape)

shap_values_cat.values = new_shap_values
shap.summary_plot(shap_values_cat.values, X_test)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.0.0"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}var l=Symbol.for("react.element"),s=Symbol.for("react.transitional.element"),c=Symbol.for("react.portal"),f=Symbol.for("react.fragment"),d=Symbol.for("react.strict_mode"),p=Symbol.for("react.profiler"),h=Symbol.for("react.p ...
# New shape: (25, 12)

# %% [markdown]
# ## Peran Peubah per kategori

# %%
import shap
import tensorflow

#save nilai
explainer = shap.TreeExplainer(model_cb_cv_best)
shap.initjs()
shap_values_cat = explainer(X_test)
prediksi = model_cb_cv.predict(X_test)

new_shap_values = []
for i in range(len(X_test)):
    new_shap_values.append(shap_values_cat.values[i][:, 0])  # kelas ke-0
new_shap_values = np.array(new_shap_values)
new_shap_values = np.squeeze(new_shap_values)
print("New shape:", new_shap_values.shape)

shap_values_cat.values = new_shap_values
shap.summary_plot(shap_values_cat.values, X_test)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.0.0"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}var l=Symbol.for("react.element"),s=Symbol.for("react.transitional.element"),c=Symbol.for("react.portal"),f=Symbol.for("react.fragment"),d=Symbol.for("react.strict_mode"),p=Symbol.for("react.profiler"),h=Symbol.for("react.p ...
# New shape: (25, 12)

# %%
import shap
import tensorflow

#save nilai
explainer = shap.TreeExplainer(model_cb_cv_best)
shap.initjs()
shap_values_cat = explainer(X_test)
prediksi = model_cb_cv.predict(X_test)

new_shap_values = []
for i in range(len(X_test)):
    new_shap_values.append(shap_values_cat.values[i][:, 1])  # kelas ke-1
new_shap_values = np.array(new_shap_values)
new_shap_values = np.squeeze(new_shap_values)
print("New shape:", new_shap_values.shape)

shap_values_cat.values = new_shap_values
shap.summary_plot(shap_values_cat.values, X_test)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.0.0"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}var l=Symbol.for("react.element"),s=Symbol.for("react.transitional.element"),c=Symbol.for("react.portal"),f=Symbol.for("react.fragment"),d=Symbol.for("react.strict_mode"),p=Symbol.for("react.profiler"),h=Symbol.for("react.p ...
# New shape: (25, 12)

# %%
import shap
import tensorflow

#save nilai
explainer = shap.TreeExplainer(model_cb_cv_best)
shap.initjs()
shap_values_cat = explainer(X_test)
prediksi = model_cb_cv.predict(X_test)

new_shap_values = []
for i in range(len(X_test)):
    new_shap_values.append(shap_values_cat.values[i][:, 2])  # kelas ke-2
new_shap_values = np.array(new_shap_values)
new_shap_values = np.squeeze(new_shap_values)
print("New shape:", new_shap_values.shape)

shap_values_cat.values = new_shap_values
shap.summary_plot(shap_values_cat.values, X_test)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.0.0"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}var l=Symbol.for("react.element"),s=Symbol.for("react.transitional.element"),c=Symbol.for("react.portal"),f=Symbol.for("react.fragment"),d=Symbol.for("react.strict_mode"),p=Symbol.for("react.profiler"),h=Symbol.for("react.p ...
# New shape: (25, 12)

# %%
import shap
import tensorflow

#save nilai
explainer = shap.TreeExplainer(model_cb_cv_best)
shap.initjs()
shap_values_cat = explainer(X_test)
prediksi = model_cb_cv.predict(X_test)

new_shap_values = []
for i in range(len(X_test)):
    new_shap_values.append(shap_values_cat.values[i][:, 3])  # kelas ke-3
new_shap_values = np.array(new_shap_values)
new_shap_values = np.squeeze(new_shap_values)
print("New shape:", new_shap_values.shape)

shap_values_cat.values = new_shap_values
shap.summary_plot(shap_values_cat.values, X_test)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.0.0"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}var l=Symbol.for("react.element"),s=Symbol.for("react.transitional.element"),c=Symbol.for("react.portal"),f=Symbol.for("react.fragment"),d=Symbol.for("react.strict_mode"),p=Symbol.for("react.profiler"),h=Symbol.for("react.p ...
# New shape: (25, 12)

# %%
import shap
import tensorflow

#save nilai
explainer = shap.TreeExplainer(model_cb_cv_best)
shap.initjs()
shap_values_cat = explainer(X_test)
prediksi = model_cb_cv.predict(X_test)

new_shap_values = []
for i in range(len(X_test)):
    new_shap_values.append(shap_values_cat.values[i][:, 4])  # kelas ke-4
new_shap_values = np.array(new_shap_values)
new_shap_values = np.squeeze(new_shap_values)
print("New shape:", new_shap_values.shape)

shap_values_cat.values = new_shap_values
shap.summary_plot(shap_values_cat.values, X_test)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.0.0"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}var l=Symbol.for("react.element"),s=Symbol.for("react.transitional.element"),c=Symbol.for("react.portal"),f=Symbol.for("react.fragment"),d=Symbol.for("react.strict_mode"),p=Symbol.for("react.profiler"),h=Symbol.for("react.p ...
# New shape: (25, 12)
