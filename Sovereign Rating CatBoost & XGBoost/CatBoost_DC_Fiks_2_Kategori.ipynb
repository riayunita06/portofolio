# %% [markdown]
# # Pra Proses Data

# %%
! pip install klib

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import klib

# %%
df = pd.read_excel('/content/Data DC.xlsx')
df
# Out:
#          Country Sovereign  Kategori  GDP (USDbn)  Real GDP Growth (%)  \
# 0    Switzerland       AAA         0          925                  1.3
# 1        Germany       AAA         0         4658                 -0.2
# 2        Denmark       AAA         0          426                  2.3
# 3     Luxembourg       AAA         0           93                  1.0
# 4    Netherlands       AAA         0         1225                  0.9
# ..           ...       ...       ...          ...                  ...
# 117   Bangladesh        B+         1          449                  4.2
# 118     Mongolia        B+         1           24                  5.0
# 119    Sri Lanka      CCC+         1           99                  5.0
# 120     Pakistan      CCC+         1          373                  2.5
# 121     Maldives        CC         1            7                  5.3
#
#      GDP Volatility (10 yr roll (%))  Consumer prices (annual avg. % growth)  \
# ...

# %%
df.isnull().sum()
# Out:
# Country                                   0
# Sovereign                                 0
# Kategori                                  0
# GDP (USDbn)                               0
# Real GDP Growth (%)                       0
# GDP Volatility (10 yr roll (%))           0
# Consumer prices (annual avg. % growth)    0
# GG balance (% GDP)                        0
# GG debt (% GDP)                           0
# Comm. Dep (%CXR)                          0
# GG int. exp. (% revenue)                  0
# GG dom. debt (% GDP)                      0
# GXD (% GDP)                               0
# GDP per. cap. (USD)                       0
# Pol. stability                            0
# Reg. Qual.                                0
# CAB (% GDP)                               0
# dtype: int64

# %%
df.describe()
# Out:
#          Kategori   GDP (USDbn)  Real GDP Growth (%)  \
# count  122.000000    122.000000           122.000000
# mean     0.491803    874.598361             2.893443
# std      0.501994   3187.335146             2.335983
# min      0.000000      2.000000            -2.800000
# 25%      0.000000     43.000000             1.225000
# 50%      0.000000    123.000000             2.800000
# 75%      1.000000    488.000000             4.300000
# max      1.000000  29184.000000             9.400000
#
#        GDP Volatility (10 yr roll (%))  \
# count                       122.000000
# mean                          3.946721
# std                           3.509943
# min                           1.000000
# 25%                           2.300000
# 50%                           3.300000
# 75%                           4.400000
# max                          33.600000
#
#        Consumer prices (annual avg. % growth)  GG balance (% GDP)  \
# ...

# %%
# prompt: buatkan syntax cek jenis data di tiap kolom

df.dtypes
# Out:
# Country                                    object
# Sovereign                                  object
# Kategori                                    int64
# GDP (USDbn)                                 int64
# Real GDP Growth (%)                       float64
# GDP Volatility (10 yr roll (%))           float64
# Consumer prices (annual avg. % growth)    float64
# GG balance (% GDP)                        float64
# GG debt (% GDP)                           float64
# Comm. Dep (%CXR)                          float64
# GG int. exp. (% revenue)                  float64
# GG dom. debt (% GDP)                      float64
# GXD (% GDP)                               float64
# GDP per. cap. (USD)                         int64
# Pol. stability                            float64
# Reg. Qual.                                float64
# CAB (% GDP)                               float64
# dtype: object

# %%
from scipy.stats import f_oneway
import pandas as pd
from scipy.stats import f_oneway

# %%
# Grouping GDP berdasarkan kategori target
groups = [group['GDP (USDbn)'].values for name, group in df.groupby('Kategori')]

# Lakukan ANOVA
f_stat, p_value = f_oneway(*groups)

print("F-statistic:", f_stat)
print("p-value:", p_value)
# Out:
# F-statistic: 6.089635892800429
# p-value: 0.0150077310909042

# %%
# Grouping GDP berdasarkan kategori target
groups = [group['Real GDP Growth (%)'].values for name, group in df.groupby('Kategori')]

# Lakukan ANOVA
f_stat, p_value = f_oneway(*groups)

print("F-statistic:", f_stat)
print("p-value:", p_value)
# Out:
# F-statistic: 7.080962107638708
# p-value: 0.008856950589984893

# %%
# Grouping GDP berdasarkan kategori target
groups = [group['GDP Volatility (10 yr roll (%))'].values for name, group in df.groupby('Kategori')]

# Lakukan ANOVA
f_stat, p_value = f_oneway(*groups)

print("F-statistic:", f_stat)
print("p-value:", p_value)
# Out:
# F-statistic: 0.0006687012554378567
# p-value: 0.9794125499833397

# %%
# Grouping GDP berdasarkan kategori target
groups = [group['Consumer prices (annual avg. % growth)'].values for name, group in df.groupby('Kategori')]

# Lakukan ANOVA
f_stat, p_value = f_oneway(*groups)

print("F-statistic:", f_stat)
print("p-value:", p_value)
# Out:
# F-statistic: 4.318856057408384
# p-value: 0.03982409601616038

# %%
# Grouping GDP berdasarkan kategori target
groups = [group['GG balance (% GDP)'].values for name, group in df.groupby('Kategori')]

# Lakukan ANOVA
f_stat, p_value = f_oneway(*groups)

print("F-statistic:", f_stat)
print("p-value:", p_value)
# Out:
# F-statistic: 5.324907858858634
# p-value: 0.022736031495065437

# %%
# Grouping GDP berdasarkan kategori target
groups = [group['GG debt (% GDP)'].values for name, group in df.groupby('Kategori')]

# Lakukan ANOVA
f_stat, p_value = f_oneway(*groups)

print("F-statistic:", f_stat)
print("p-value:", p_value)
# Out:
# F-statistic: 0.33768175912377324
# p-value: 0.5622602773536092

# %%
# Grouping GDP berdasarkan kategori target
groups = [group['Comm. Dep (%CXR)'].values for name, group in df.groupby('Kategori')]

# Lakukan ANOVA
f_stat, p_value = f_oneway(*groups)

print("F-statistic:", f_stat)
print("p-value:", p_value)
# Out:
# F-statistic: 10.03489013380769
# p-value: 0.0019483991044759587

# %%
# Grouping GDP berdasarkan kategori target
groups = [group['GG int. exp. (% revenue)'].values for name, group in df.groupby('Kategori')]

# Lakukan ANOVA
f_stat, p_value = f_oneway(*groups)

print("F-statistic:", f_stat)
print("p-value:", p_value)
# Out:
# F-statistic: 32.73981031912818
# p-value: 7.896254216728473e-08

# %%
# Grouping GDP berdasarkan kategori target
groups = [group['GG dom. debt (% GDP)'].values for name, group in df.groupby('Kategori')]

# Lakukan ANOVA
f_stat, p_value = f_oneway(*groups)

print("F-statistic:", f_stat)
print("p-value:", p_value)
# Out:
# F-statistic: 3.675376310169633
# p-value: 0.05759913692028925

# %%
# Grouping GDP berdasarkan kategori target
groups = [group['GXD (% GDP)'].values for name, group in df.groupby('Kategori')]

# Lakukan ANOVA
f_stat, p_value = f_oneway(*groups)

print("F-statistic:", f_stat)
print("p-value:", p_value)
# Out:
# F-statistic: 4.1537464185923385
# p-value: 0.04374071107166481

# %%
# Grouping GDP berdasarkan kategori target
groups = [group['GDP per. cap. (USD)'].values for name, group in df.groupby('Kategori')]

# Lakukan ANOVA
f_stat, p_value = f_oneway(*groups)

print("F-statistic:", f_stat)
print("p-value:", p_value)
# Out:
# F-statistic: 84.0570429485578
# p-value: 1.6400954840108181e-15

# %%
# Grouping GDP berdasarkan kategori target
groups = [group['Pol. stability'].values for name, group in df.groupby('Kategori')]

# Lakukan ANOVA
f_stat, p_value = f_oneway(*groups)

print("F-statistic:", f_stat)
print("p-value:", p_value)
# Out:
# F-statistic: 44.67072823067513
# p-value: 7.754216994235965e-10

# %%
# Grouping GDP berdasarkan kategori target
groups = [group['Reg. Qual.'].values for name, group in df.groupby('Kategori')]

# Lakukan ANOVA
f_stat, p_value = f_oneway(*groups)

print("F-statistic:", f_stat)
print("p-value:", p_value)
# Out:
# F-statistic: 156.99595874638868
# p-value: 1.529415906158876e-23

# %%
# Grouping GDP berdasarkan kategori target
groups = [group['CAB (% GDP)'].values for name, group in df.groupby('Kategori')]

# Lakukan ANOVA
f_stat, p_value = f_oneway(*groups)

print("F-statistic:", f_stat)
print("p-value:", p_value)
# Out:
# F-statistic: 23.759181645126148
# p-value: 3.3779040800147577e-06

# %% [markdown]
# # Eksplorasi Data

# %% [markdown]
# ## Cek Korelasi antar Peubah Independen

# %%
df.corr(numeric_only=True)

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriks Korelasi Variabel Numerik')
plt.show()

# %% [markdown]
# Nilai korelasi antar peubah independen tidak menunjukkan tanda tanda multikolinearitas sehingga semua peubah independen diatas dapat digunakan

# %% [markdown]
# ## Ekplorasi Peubah Numerik

# %%
# prompt: buatkan syntax untuk membuat boxplot dari peubah numerik df, buatkan tampilan boxplotnya vertikal

import matplotlib.pyplot as plt
import numpy as np
# Assuming 'df' is your DataFrame and contains numerical columns you want to plot.
# Replace 'numerical_column' with the actual name of the numerical column you want to visualize.

numerical_columns = df.select_dtypes(include=np.number).columns

for column in numerical_columns:
  plt.figure(figsize=(8, 6))
  sns.boxplot(y=df[column], orient='v') # vertical boxplot
  plt.title(f'Boxplot of {column}')
  plt.ylabel(column)
  plt.show()

# %%
# prompt: buatkan eksplorasi histogram semua variabel numerik dari df

import numpy as np
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame and contains numerical columns you want to plot.
# Replace 'numerical_column' with the actual name of the numerical column you want to visualize.

numerical_columns = df.select_dtypes(include=np.number).columns

for column in numerical_columns:
  plt.figure(figsize=(8, 6))
  sns.histplot(df[column], kde=True)  # Histogram with KDE
  plt.title(f'Histogram of {column}')
  plt.xlabel(column)
  plt.ylabel('Frequency')
  plt.show()

# %% [markdown]
# ## Eksplorasi Sebaran Peubah Kategorik

# %%
# prompt: buatkan barchart untuk variabel kategori di df dan ganti nama elemennya dimana angka 1 = Sovereign Elite, 2 =Strong Investment Grade, 3 = Lower Investment Grade, 4 =Non-Investment Grade (Upper Tier), 5  =Distressed and Defaulted

# Assuming 'df' is your DataFrame and contains a categorical column named 'kategori'.
# Replace 'kategori' with the actual name of your categorical column.

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.countplot(x='Kategori', data=df)
plt.title('Distribution of Kategori')
plt.xlabel('Kategori')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent labels from overlapping
plt.show()

# %% [markdown]
# # Pembagian Data Train dan Testing

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
# prompt: buatkan variabel X dimana isinya selain peubah Country, Sovereign, Kategori

X = df.drop(columns=['Country', 'Sovereign', 'Kategori'])
Y = df['Kategori']

# %%
# prompt: buatkan syntax pembagian data train dan testing dari X dan Y

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (97, 14)
# (25, 14)
# (97,)
# (25,)

# %%
#normalisasi
scaler = MinMaxScaler()
skalax =scaler.fit(X_train)
X_train_scaled =skalax.transform(X_train)
X_train =pd.DataFrame(X_train_scaled, columns=X_train.columns)

X_test_Scaled =skalax.transform(X_test)
X_test= pd.DataFrame(X_test_Scaled, columns=X_test.columns)

# %% [markdown]
# # Pemodelan CatBoost Tanpa Penanganan

# %%
# --- Import library yang diperlukan ---
# !pip install catboost
import numpy as np
import pandas as pd

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_validate, KFold
from catboost import CatBoostClassifier

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# %% [markdown]
# ## Tuning Hyperparameter 1

# %%
# nilai-nilai hyperparameter
param_dist = {
    'iterations': [25,50,100, 200, 300],
    'depth': [2,3],
    'learning_rate': [0.01, 0.05, 0.1, 0.3, 0.5],
    'l2_leaf_reg': [1, 3, 5, 7, 9],
    'loss_function': ['Logloss']
}

# %% [markdown]
# ## Random Search dan Cross Validation 1

# %%
from sklearn.model_selection import RandomizedSearchCV

# Definisikan model awal dan parameter untuk RandomizedSearchCV
base_model = CatBoostClassifier(loss_function="Logloss", verbose=0)

random_search = RandomizedSearchCV(
    base_model,
    param_distributions=param_dist,
    n_iter=50,
    scoring="accuracy",
    cv=5,                 # Cross-validation 5-fold
    random_state=42,      # Random seed untuk hasil yang dapat direproduksi
    n_jobs=-1,            # Menggunakan semua core CPU yang tersedia
)

# Melakukan random search dan fitting data training
random_search.fit(X_train, Y_train)

# Menampilkan parameter terbaik
print(f"Best parameters found: {random_search.best_params_}")

# Menampilkan skor akurasi terbaik hasil CV
print(f"Best CV Score: {random_search.best_score_}")
# Out:
# Best parameters found: {'loss_function': 'Logloss', 'learning_rate': 0.05, 'l2_leaf_reg': 3, 'iterations': 100, 'depth': 3}
# Best CV Score: 0.8968421052631579

# %% [markdown]
# ## Evaluasi Model Terbaik 1

# %%
# Memilih model terbaik
model_cb_cv = random_search.best_estimator_

# Memprediksi data uji
y_pred_cv = model_cb_cv.predict(X_train)

# Menghitung akurasi
accuracy_cv = accuracy_score(Y_train, y_pred_cv)

print(f"Accuracy: {accuracy_cv}")

cm_cv = confusion_matrix(Y_train, y_pred_cv)
print("\nConfusion Matrix:\n", cm_cv)

cr_cv = classification_report(Y_train, y_pred_cv)
print("\nClassification Report:\n", cr_cv)
# Out:
# Accuracy: 0.9690721649484536
#
# Confusion Matrix:
#  [[45  2]
#  [ 1 49]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97        47
#            1       0.96      0.98      0.97        50
#
#     accuracy                           0.97        97
#    macro avg       0.97      0.97      0.97        97
# weighted avg       0.97      0.97      0.97        97

# %%
# Memilih model terbaik
model_cb_cv = random_search.best_estimator_

# Memprediksi data uji
y_pred_cv = model_cb_cv.predict(X_test)

# Menghitung akurasi
accuracy_cv = accuracy_score(Y_test, y_pred_cv)

print(f"Accuracy: {accuracy_cv}")

cm_cv = confusion_matrix(Y_test, y_pred_cv)
print("\nConfusion Matrix:\n", cm_cv)

cr_cv = classification_report(Y_test, y_pred_cv)
print("\nClassification Report:\n", cr_cv)
# Out:
# Accuracy: 0.92
#
# Confusion Matrix:
#  [[13  2]
#  [ 0 10]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93        15
#            1       0.83      1.00      0.91        10
#
#     accuracy                           0.92        25
#    macro avg       0.92      0.93      0.92        25
# weighted avg       0.93      0.92      0.92        25

# %% [markdown]
# ## Tuning Hyperparameter 2 dan Grid Search

# %%
from sklearn.model_selection import GridSearchCV
from catboost import CatBoostClassifier

# Nilai-nilai hyperparameter
param_grid = {
    'iterations': [25, 50, 100],
    'depth': [2, 3],
    'learning_rate': [0.01, 0.05, 0.1, 0.3, 0.5],
    'l2_leaf_reg': [1, 3, 5, 7, 9],
    'loss_function': ['Logloss']
}

# Definisikan model awal
base_model = CatBoostClassifier(loss_function="Logloss", verbose=0)

# Definisikan GridSearchCV dengan early stopping
grid_search = GridSearchCV(
    base_model,
    param_grid=param_grid,
    scoring="accuracy",
    cv=5,                 # Cross-validation 5-fold
    n_jobs=-1,            # Menggunakan semua core CPU yang tersedia
)

# Melakukan grid search dan fitting data training dengan early stopping
grid_search.fit(X_train, Y_train,
                early_stopping_rounds=10)  # Menambahkan early stopping dengan 10 rounds

# Menampilkan parameter terbaik
print(f"Best parameters found: {grid_search.best_params_}")

# Menampilkan skor akurasi terbaik hasil CV
print(f"Best CV Score: {grid_search.best_score_}")
# Out:
# Best parameters found: {'depth': 2, 'iterations': 50, 'l2_leaf_reg': 7, 'learning_rate': 0.5, 'loss_function': 'Logloss'}
# Best CV Score: 0.9073684210526315

# %% [markdown]
# ## Evaluasi Model Terbaik 2

# %%
# Memilih model terbaik
model_cb_cv = grid_search.best_estimator_

# Memprediksi data uji
y_pred_cv = model_cb_cv.predict(X_train)

# Menghitung akurasi
accuracy_cv = accuracy_score(Y_train, y_pred_cv)

print(f"Accuracy: {accuracy_cv}")

# Menghitung confusion matrix
cm_cv = confusion_matrix(Y_train, y_pred_cv)
print("\nConfusion Matrix:\n", cm_cv)

# Menampilkan classification report
cr_cv = classification_report(Y_train, y_pred_cv)
print("\nClassification Report:\n", cr_cv)
# Out:
# Accuracy: 1.0
#
# Confusion Matrix:
#  [[47  0]
#  [ 0 50]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        47
#            1       1.00      1.00      1.00        50
#
#     accuracy                           1.00        97
#    macro avg       1.00      1.00      1.00        97
# weighted avg       1.00      1.00      1.00        97

# %%
# Memilih model terbaik
model_cb_cv = grid_search.best_estimator_

# Memprediksi data uji
y_pred_cv = model_cb_cv.predict(X_test)

# Menghitung akurasi
accuracy_cv = accuracy_score(Y_test, y_pred_cv)

print(f"Accuracy: {accuracy_cv}")
# Evaluasi metrik
print("Akurasi:", accuracy_score(Y_test, y_pred_cv))
print("Precision (macro):", precision_score(Y_test, y_pred_cv, average='macro'))
print("Recall (macro):", recall_score(Y_test, y_pred_cv, average='macro'))
print("F1 Score (macro):", f1_score(Y_test, y_pred_cv, average='macro'))

# Menghitung confusion matrix
cm_cv = confusion_matrix(Y_test, y_pred_cv)
print("\nConfusion Matrix:\n", cm_cv)

# Menampilkan classification report
cr_cv = classification_report(Y_test, y_pred_cv)
print("\nClassification Report:\n", cr_cv)
# Out:
# Accuracy: 0.88
# Akurasi: 0.88
# Precision (macro): 0.8846153846153846
# Recall (macro): 0.9
# F1 Score (macro): 0.8792270531400965
#
# Confusion Matrix:
#  [[12  3]
#  [ 0 10]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89        15
#            1       0.77      1.00      0.87        10
#
#     accuracy                           0.88        25
#    macro avg       0.88      0.90      0.88        25
# weighted avg       0.91      0.88      0.88        25

# %% [markdown]
# ## Tuning Hyperparameter 3 & Grid Search (Best model)

# %%
from sklearn.model_selection import GridSearchCV
from catboost import CatBoostClassifier

# Nilai-nilai hyperparameter
param_grid = {
'iterations': [25, 50, 100],
    'depth': [2,3],
    'learning_rate': [0.01, 0.05],
    'l2_leaf_reg': [1, 3, 5, 7, 9],
    'loss_function':['Logloss']
}

# Definisikan model awal
base_model = CatBoostClassifier(loss_function="Logloss", verbose=0)

# Definisikan GridSearchCV
grid_search = GridSearchCV(
    base_model,
    param_grid=param_grid,
    scoring="accuracy",
    cv=5,                 # Cross-validation 5-fold
    n_jobs=-1,            # Menggunakan semua core CPU yang tersedia
)

# Melakukan grid search dan fitting data training
grid_search.fit(X_train, Y_train)

# Menampilkan parameter terbaik
print(f"Best parameters found: {grid_search.best_params_}")

# Menampilkan skor akurasi terbaik hasil CV
print(f"Best CV Score: {grid_search.best_score_}")
# Out:
# Best parameters found: {'depth': 2, 'iterations': 100, 'l2_leaf_reg': 1, 'learning_rate': 0.05, 'loss_function': 'Logloss'}
# Best CV Score: 0.8968421052631579

# %% [markdown]
# ## Evaluasi Model Terbaik 3

# %%
# Memilih model terbaik
model_cb_cv_best = grid_search.best_estimator_

# Memprediksi data uji
y_pred_cv = model_cb_cv_best.predict(X_train)

# Menghitung akurasi
accuracy_cv = accuracy_score(Y_train, y_pred_cv)

print(f"Accuracy: {accuracy_cv}")

# Menghitung confusion matrix
cm_cv = confusion_matrix(Y_train, y_pred_cv)
print("\nConfusion Matrix:\n", cm_cv)

# Menampilkan classification report
cr_cv = classification_report(Y_train, y_pred_cv)
print("\nClassification Report:\n", cr_cv)
# Out:
# Accuracy: 0.9690721649484536
#
# Confusion Matrix:
#  [[45  2]
#  [ 1 49]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97        47
#            1       0.96      0.98      0.97        50
#
#     accuracy                           0.97        97
#    macro avg       0.97      0.97      0.97        97
# weighted avg       0.97      0.97      0.97        97

# %%
# Memilih model terbaik
model_cb_cv = grid_search.best_estimator_

# Memprediksi data uji
y_pred_cv = model_cb_cv.predict(X_test)

# Menghitung akurasi
accuracy_cv = accuracy_score(Y_test, y_pred_cv)

print(f"Accuracy: {accuracy_cv}")
# Evaluasi metrik
print("Akurasi:", accuracy_score(Y_test, y_pred_cv))
print("Precision (macro):", precision_score(Y_test, y_pred_cv, average='macro'))
print("Recall (macro):", recall_score(Y_test, y_pred_cv, average='macro'))
print("F1 Score (macro):", f1_score(Y_test, y_pred_cv, average='macro'))

# Menghitung confusion matrix
cm_cv = confusion_matrix(Y_test, y_pred_cv)
print("\nConfusion Matrix:\n", cm_cv)

# Menampilkan classification report
cr_cv = classification_report(Y_test, y_pred_cv)
print("\nClassification Report:\n", cr_cv)
# Out:
# Accuracy: 0.92
# Akurasi: 0.92
# Precision (macro): 0.9166666666666667
# Recall (macro): 0.9166666666666667
# F1 Score (macro): 0.9166666666666667
#
# Confusion Matrix:
#  [[14  1]
#  [ 1  9]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93        15
#            1       0.90      0.90      0.90        10
#
#     accuracy                           0.92        25
#    macro avg       0.92      0.92      0.92        25
# weighted avg       0.92      0.92      0.92        25

# %% [markdown]
# ## Tuning Hyperparameter 4 & Grid Search (Paling OKe)

# %%
from sklearn.model_selection import GridSearchCV
from catboost import CatBoostClassifier

# Nilai-nilai hyperparameter
param_grid = {
'iterations': [25],
    'depth': [2,3],
    'learning_rate': [0.01, 0.05],
    'l2_leaf_reg': [2],
    'loss_function':['Logloss']
}

# Definisikan model awal
base_model = CatBoostClassifier(loss_function="Logloss", verbose=0)

# Definisikan GridSearchCV
grid_search = GridSearchCV(
    base_model,
    param_grid=param_grid,
    scoring="accuracy",
    cv=5,                 # Cross-validation 5-fold
    n_jobs=-1,            # Menggunakan semua core CPU yang tersedia
)

# Melakukan grid search dan fitting data training
grid_search.fit(X_train, Y_train)

# Menampilkan parameter terbaik
print(f"Best parameters found: {grid_search.best_params_}")

# Menampilkan skor akurasi terbaik hasil CV
print(f"Best CV Score: {grid_search.best_score_}")
# Out:
# Best parameters found: {'depth': 2, 'iterations': 25, 'l2_leaf_reg': 2, 'learning_rate': 0.01, 'loss_function': 'Logloss'}
# Best CV Score: 0.8547368421052631

# %%
# Memilih model terbaik
model_cb_cv = grid_search.best_estimator_

# Memprediksi data uji
y_pred_cv = model_cb_cv.predict(X_train)

# Menghitung akurasi
accuracy_cv = accuracy_score(Y_train, y_pred_cv)

print(f"Accuracy: {accuracy_cv}")

# Menghitung confusion matrix
cm_cv = confusion_matrix(Y_train, y_pred_cv)
print("\nConfusion Matrix:\n", cm_cv)

# Menampilkan classification report
cr_cv = classification_report(Y_train, y_pred_cv)
print("\nClassification Report:\n", cr_cv)
# Out:
# Accuracy: 0.8865979381443299
#
# Confusion Matrix:
#  [[40  7]
#  [ 4 46]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88        47
#            1       0.87      0.92      0.89        50
#
#     accuracy                           0.89        97
#    macro avg       0.89      0.89      0.89        97
# weighted avg       0.89      0.89      0.89        97

# %% [markdown]
# ## Evaluasi Model Terbaik 4

# %%
# Memilih model terbaik
model_cb_cv = grid_search.best_estimator_

# Memprediksi data uji
y_pred_cv = model_cb_cv.predict(X_test)

# Menghitung akurasi
accuracy_cv = accuracy_score(Y_test, y_pred_cv)

print(f"Accuracy: {accuracy_cv}")
# Evaluasi metrik
print("Akurasi:", accuracy_score(Y_test, y_pred_cv))
print("Precision (macro):", precision_score(Y_test, y_pred_cv, average='macro'))
print("Recall (macro):", recall_score(Y_test, y_pred_cv, average='macro'))
print("F1 Score (macro):", f1_score(Y_test, y_pred_cv, average='macro'))

# Menghitung confusion matrix
cm_cv = confusion_matrix(Y_test, y_pred_cv)
print("\nConfusion Matrix:\n", cm_cv)

# Menampilkan classification report
cr_cv = classification_report(Y_test, y_pred_cv)
print("\nClassification Report:\n", cr_cv)
# Out:
# Accuracy: 0.84
# Akurasi: 0.84
# Precision (macro): 0.8365384615384616
# Recall (macro): 0.8500000000000001
# F1 Score (macro): 0.8376623376623377
#
# Confusion Matrix:
#  [[12  3]
#  [ 1  9]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.80      0.86        15
#            1       0.75      0.90      0.82        10
#
#     accuracy                           0.84        25
#    macro avg       0.84      0.85      0.84        25
# weighted avg       0.85      0.84      0.84        25

# %%
import joblib

model_filename = 'model_catboost.pkl'
joblib.dump(model_cb_cv_best, model_filename)
print(f"Model saved to {model_filename}")
# Out:
# Model saved to model_catboost.pkl

# %%
loaded_model = joblib.load(model_filename)
print(f"Model loaded from {model_filename}")
# Out:
# Model loaded from model_catboost.pkl

# %% [markdown]
# ## Feature Important Global

# %%
import matplotlib.pyplot as plt

# Menampilkan Fitur Importance
feature_importances = loaded_model.feature_importances_
feature_names = X.columns

# Membuat DataFrame untuk Fitur Importance
feature_importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=False)

# Menampilkan DataFrame Fitur Importance
print("\nFeature Importances:")
print(feature_importance_df)

# Membuat Plot Fitur Importance
plt.figure(figsize=(6, 4))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importances')
plt.gca().invert_yaxis()
plt.show()
# Out:
# Feature Importances:
#                                    Feature  Importance
# 10                     GDP per. cap. (USD)   34.911798
# 12                              Reg. Qual.   23.215700
# 0                              GDP (USDbn)   18.593963
# 7                 GG int. exp. (% revenue)   10.365073
# 3   Consumer prices (annual avg. % growth)    4.326163
# 2          GDP Volatility (10 yr roll (%))    2.854143
# 13                             CAB (% GDP)    2.333678
# 9                              GXD (% GDP)    1.491843
# 5                          GG debt (% GDP)    0.558121
# 6                         Comm. Dep (%CXR)    0.510096
# 11                          Pol. stability    0.472544
# 1                      Real GDP Growth (%)    0.275099
# 4                       GG balance (% GDP)    0.061781
# 8                     GG dom. debt (% GDP)    0.029997

# %% [markdown]
# ## Peran Peubah secara Global

# %%
import shap

# Menghitung SHAP values untuk data uji
explainer = shap.TreeExplainer(model_cb_cv_best)
shap.initjs()
shap_values_cat = explainer(X_test)

# Plot SHAP Global summary untuk semua kelas
shap.summary_plot(shap_values_cat.values, X_test)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...
